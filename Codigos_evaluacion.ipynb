# %% [markdown]
# ## Codigos de registro para presentar evaluaciones

# %% [markdown]
# A continuacion usted encontrara el codigo que le permitira acceder a la plataforma ClassMarker, tenga en cuenta:
#
# - EL codigo es personal e intransferible
# - No use el codigo asignado a otra persona, esto le implicará sanciones
# - El codigo solo se puede usar UNA VEZ

# %% [markdown]
# ## Códigos

# %% [markdown]
# |   Primer Apellido  |   Segundo apellido  |   Primer nombre  |   Segundo nombre  |   Codigo          |
# |--------------------|---------------------|------------------|-------------------|-------------------|
# |   ALFONSO          |   CALDON            |   JULIAN         |   STEVEN          |   DC8115835208PD  |
# |   ALVAREZ          |   ZAVALA            |   ANGEL          |   GABRIEL         |   3D2115835200H3  |
# |   ARBOLEDA         |   ALONSO            |   YAHANNAH       |   SOFIA           |   BA9115835207XG  |
# |   BARRETO          |   GARAVITO          |   YOHAN          |   SAMUEL          |   FP81158352016K  |
# |   BELTRAN          |   PEÑA              |   JUAN           |   PABLO           |   FN01158352039G  |
# |   CASTILLO         |   RAMIREZ           |   SAMUEL         |   FELIPE          |   9D2115835204EM  |
# |   CASTRILLON       |   OCHOA             |   DIEGO          |   ANDRES          |   4Q711583520464  |
# |   CERQUERA         |   URRIAGO           |   GERSON         |   ANDRES          |   9V8115835203P7  |
# |   CORTES           |   GARZON            |   CAMILO         |   ANDRES          |   PB61158352096X  |
# |   CORTES           |   TORRES            |   SHARON         |   MARCELA         |   PY3115835207CG  |
# |   FONTALVO         |   ANDRADE           |   YASER          |   DAVID           |   Y70115835209NX  |
# |   GONZALEZ         |   RODRIGUEZ         |   JHOAN          |   ANDREY          |   PK411583520339  |
# |   GUTIERREZ        |   OLIVARES          |   LUIS           |   EDUARDO         |   J991158352006X  |
# |   JIMENEZ          |   ZAPATA            |   MARIA          |   PAZ             |   3C611583520367  |
# |   LAVERDE          |   GAITAN            |   AXEL           |   STEVE           |   CG7115835204PG  |
# |   OROPEZA          |   AULAR             |   YRANSUYS       |   MARIANGEL       |   DK4115835200QV  |
# |   PARRA            |   BATANERO          |   VALERY         |   SOFIA           |   RB0115835203KM  |
# |   PEREA            |   RAMIREZ           |   SANTIAGO       |                   |   JV4115835200XM  |
# |   PERLAZA          |   MICHILENO         |   ALISSON        |   SOFIA           |   MG9115835209V3  |
# |   RAMIREZ          |   FERNANDEZ         |   OWEN           |   ESTEBAN         |   7H111583520844  |
# |   RODRIGUEZ        |   CALDERON          |   LESLY          |   ADRIANA         |   KX1115835208BP  |
# |   TORRES           |   NOVOA             |   RONALD         |   ALEJANDRO       |   VA5115835206FD  |
# |   TOVAR            |   SILVA             |   YESSIVEN       |   ARLEY           |   GH0115835207PF  |
# |   VELA             |                     |   LAURA          |   XIMENA          |   YG1115835200RY  |

# %% [markdown]
# ## Registro en la plataforma

# %% [markdown]
# __Unicamente__ cuando el profesor indique proceda al registro en la plataforma, haciendo clic en el siguiente enlace:

# %% [markdown]
# [Enlace a ClassMarker](https://www.classmarker.com/register/?trk=top-nav)
